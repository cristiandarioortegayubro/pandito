# %% [markdown]
# # 🚀 Módulo 01 - Notebook 01: Configuración de Databricks y Git
#
# ## 📚 Entorno de trabajo unificado con Databricks Free Edition & GitHub
#
# **Libro:** Saliendo de lo Pandito
# **Módulo:** 01 - Fundamentos de Databricks y Python
# **Duración estimada:** 30 minutos
# **Dificultad:** 🟢 Principiante
# **Plataforma:** Databricks Free Edition
#
# ---
#
# ## 🎯 Objetivos de aprendizaje
#
# Al finalizar este notebook serás capaz de:
#
# ✅ **Comprender** qué es Databricks y su arquitectura básica
# ✅ **Registrarte** en Databricks Free Edition
# ✅ **Navegar** el workspace, clusters y notebooks
# ✅ **Configurar** Git integration con tu cuenta de GitHub
# ✅ **Clonar** un repositorio de GitHub en Databricks Repos
# ✅ **Ejecutar** tu primer código Python, SQL y comandos shell
# ✅ **Diferenciar** DBFS, Unity Catalog y workspace storage
#
# ---
#
# ## 📋 Pre-requisitos
#
# * ✅ Cuenta de email válida (para registro en Databricks)
# * ✅ Cuenta de GitHub gratuita ([crear aquí](https://github.com/signup))
# * ✅ Navegador web moderno (Chrome, Firefox, Edge)
# * ❌ **NO necesitas:** experiencia previa en programación, tarjeta de crédito, ni instalar software
#
# ---
#
# ## 📖 Contenido del notebook
#
# 1. **¿Qué es Databricks?** - Introducción y casos de uso
# 2. **Arquitectura de Databricks** - Workspace, clusters, notebooks
# 3. **Registro en Free Edition** - Paso a paso
# 4. **Primer notebook interactivo** - Ejecutar código Python/SQL
# 5. **Git Integration** - Conectar GitHub para versionamiento
# 6. **DBFS vs Unity Catalog** - Sistemas de almacenamiento
# 7. **Verificación del entorno** - Confirmar que todo funciona
# 8. **Buenas prácticas** - Organización de proyectos

# %% [markdown]
# ## 🧠 1. ¿Qué es Databricks?
#
# ### Definición
#
# **Databricks** es una **plataforma unificada de análisis de datos en la nube** que combina:
#
# * 📊 **Data Engineering** - Procesar grandes volúmenes de datos
# * 🧪 **Data Science** - Entrenar modelos de machine learning
# * 📊 **Business Analytics** - Analizar datos con SQL y visualizaciones
# * 🤖 **Inteligencia Artificial** - Implementar modelos en producción
#
# Todo en **un solo lugar**, sin necesidad de configurar servidores.
#
# ---
#
# ### 🏭 ¿Por qué es relevante para analistas de negocios?
#
# #### Problema tradicional:
# ```
# 1. Datos en Excel (límite: ~1 millón de filas)
# 2. Consultas SQL en bases locales (lentas)
# 3. Reportes manuales en PowerPoint (repetitivos)
# 4. No hay versionamiento de análisis
# ```
#
# #### Solución Databricks:
# ```
# ✅ Procesar MILLONES de filas en segundos
# ✅ Notebooks interactivos (Python + SQL + visualizaciones)
# ✅ Automatización de reportes
# ✅ Versionamiento con Git (como Google Docs pero para código)
# ✅ Colaboración en tiempo real
# ```
#
# ---
#
# ### 🌐 Casos de uso empresariales
#
# | Industria | Caso de uso | Ejemplo concreto |
# |-----------|-------------|------------------|
# | **Retail** | Análisis de ventas | "Cuáles productos tienen mayor margen por región" |
# | **Finanzas** | Detección de fraude | "Transacciones atípicas en tarjetas de crédito" |
# | **Marketing** | Segmentación de clientes | "Agrupar clientes por comportamiento de compra" |
# | **Operaciones** | Optimización de inventario | "Predecir demanda futura por producto" |
# | **RRHH** | Análisis de rotación | "Factores que predicen renuncia de empleados" |
#
# ---
#
# ### 🆓 Databricks Free Edition
#
# **¿Qué obtienes GRATIS?**
#
# ✅ 15 GB de RAM
# ✅ 2 CPU cores
# ✅ Notebooks interactivos ilimitados
# ✅ Python, SQL, R, Scala
# ✅ Bibliotecas: Pandas, NumPy, PySpark, scikit-learn, etc.
# ✅ Visualizaciones integradas
# ✅ Git integration
#
# **Limitaciones:**
# ❌ No puedes crear clústeres personalizados (usas serverless)
# ❌ Sesión se cierra automáticamente después de 2 horas de inactividad
# ❌ No acceso a Unity Catalog (sistema de gobernanza avanzada)
#
# **¿Es suficiente para aprender?** ✅ ¡Absolutamente! Este libro entero se puede seguir con la versión gratuita.

# %% [markdown]
# ## 🏛️ 2. Arquitectura de Databricks: Los 3 componentes clave
#
# ### 💻 2.1 Workspace (Espacio de Trabajo)
#
# **Definición:** Es tu "escritorio virtual" en la nube donde organizas:
#
# * 📓 **Notebooks** - Documentos interactivos con código + texto + gráficos
# * 📁 **Carpetas** - Organiza proyectos (como en tu computadora)
# * 📊 **Dashboards** - Reportes visuales dinámicos
# * 🔧 **Jobs** - Tareas programadas (ej: "ejecutar reporte cada lunes 8 AM")
# * 💾 **Repos** - Repositorios de Git sincronizados
#
# **Analogía:** Es como Google Drive, pero para análisis de datos.
#
# ---
#
# ### ⚡ 2.2 Clusters (Máquinas de cómputo)
#
# **Definición:** Son las "computadoras virtuales" que ejecutan tu código.
#
# #### Tipos de Compute:
#
# **A) All-Purpose Clusters (Versión paga)**
# * Tú configuras: cantidad de RAM, CPUs, tipo de máquina
# * Se mantiene activo todo el tiempo que quieras
# * Costo: ~$0.30-$5.00 por hora (según specs)
#
# **B) Serverless Compute (⭐ Lo que usaremos - GRATIS)**
# * ✅ Databricks lo gestiona automáticamente
# * ✅ Se activa al ejecutar una celda
# * ✅ Se apaga automáticamente tras inactividad
# * ✅ **Sin costo** en Community Edition
# * ⚠️ Limitación: Solo Python, SQL y comandos shell (no R ni Scala)
#
# **💡 Tip:** En Community Edition, **no ves el botón de "Start Cluster"** porque el compute serverless se inicia solo.
#
# ---
#
# ### 📓 2.3 Notebooks (Cuadernos interactivos)
#
# **Definición:** Documento que combina:
#
# 1. **Código ejecutable** (Python, SQL, sh)
# 2. **Texto formateado** (markdown) - para explicaciones
# 3. **Resultados** (tablas, gráficos, números)
#
# #### Estructura de un notebook:
#
# ```
# +-------------------------------------------+
# | Celda 1: Markdown (Título y explicación)  |
# +-------------------------------------------+
# | Celda 2: Python (importar bibliotecas)    |
# +-------------------------------------------+
# | Celda 3: SQL (consultar base de datos)    |
# +-------------------------------------------+
# | Celda 4: Python (procesar datos)          |
# +-------------------------------------------+
# | Celda 5: Visualización (gráfico)          |
# +-------------------------------------------+
# ```
#
# **Ventajas vs Excel:**
#
# | Característica | Excel | Databricks notebook |
# |----------------|-------|-----------|
# | Límite de filas | 1,048,576 | Miles de millones |
# | Lenguajes | Fórmulas de Excel | Python, SQL, R, Scala |
# | Versionamiento | Manual (Archivo_v1.xlsx) | Git (automático) |
# | Colaboración | Enviar por email | Tiempo real |
# | Automatización | Macros (limitadas) | Jobs programados |
# | Documentación | Hojas separadas | Markdown integrado |
#
# ---
#
# ### 📊 Diagrama de Arquitectura Simplificado
#
# ```
#          Usuario (Tú)
#               |
#               v
#       +---------------+
#       |   WORKSPACE   |  <-- Tu "escritorio" en la nube
#       |               |
#       | - Notebooks   |
#       | - Carpetas    |
#       | - Dashboards  |
#       +-------+-------+
#               |
#               v
#       +---------------+
#       | SERVERLESS    |  <-- Compute automático (gratis)
#       | COMPUTE       |
#       | (Python/SQL)  |
#       +-------+-------+
#               |
#               v
#       +---------------+
#       |   STORAGE     |  <-- Almacenamiento de datos
#       |               |
#       | - DBFS        | (File system)
#       | - Tables      | (Bases de datos)
#       +---------------+
# ```

# %% [markdown]
# ## 🔧 3. Verificación del Entorno de Ejecución
#
# ### ¿Por qué verificar el entorno?
#
# Antes de comenzar a trabajar con datos y análisis, es fundamental confirmar que todos los componentes de tu entorno Databricks están funcionando correctamente.
#
# ### 🎯 Objetivo de esta verificación
#
# Ejecutaremos un script simple que valida:
#
# * ✅ **Versión de Python** - Confirma que tienes Python 3.9 o superior
# * ✅ **Plataforma de ejecución** - Verifica que estás en Databricks o un entorno compatible
# * ✅ **Módulos del sistema** - Asegura que los módulos básicos están disponibles
#
# ### 💡 ¿Qué esperar?
#
# Al ejecutar la siguiente celda verás:
# * La versión exacta de Python instalada
# * El sistema operativo subyacente
# * Confirmación de que el entorno está listo
#
# **⚡ Ejecuta la celda siguiente para verificar tu entorno**

# %% [markdown]
# ## 🎯 4. Tu Primer Código Python en Databricks
#
# ### 🐍 Python: El lenguaje más usado en Data Science
#
# **¿Por qué Python?**
#
# * 📊 **Sintaxis simple** - Fácil de leer y escribir
# * 🔧 **Bibliotecas poderosas** - Pandas, NumPy, scikit-learn
# * 🌍 **Comunidad masiva** - Millones de recursos y tutoriales
# * 💼 **Demanda laboral** - Skill más solicitado en Data Analytics
#
# ---
#
# ### 📝 Anatomía de un script Python
#
# ```python
# import sys              # 1️⃣ Importar módulos
# import platform
#
# versión = sys.version   # 2️⃣ Asignar variables
#
# print(versión)          # 3️⃣ Mostrar resultados
# ```
#
# **Componentes clave:**
#
# 1. **Imports** - Traer funcionalidad externa
# 2. **Variables** - Almacenar datos en memoria
# 3. **Funciones** - Ejecutar acciones (print, len, sum, etc.)
#
# ---
#
# ### 🧪 Ejercicio 1: Script de verificación completo
#
# La siguiente celda:
#
# ✅ Importa módulos del sistema
# ✅ Obtiene información del entorno
# ✅ Formatea y muestra resultados
# ✅ Usa f-strings para interpolación de texto
#
# **Conceptos nuevos:**
#
# * `import` - Cargar bibliotecas
# * `print()` - Mostrar en pantalla
# * `f"texto {variable}"` - String formatting (f-strings)
# * `datetime.now()` - Obtener fecha/hora actual
#
# **⚡ Ejecuta la celda siguiente y observa el output**

# %% [markdown]
# ## 🔷 5. Tu Primera Consulta SQL en Databricks
#
# ### 🗄️ SQL: El lenguaje universal de datos
#
# **¿Por qué SQL es fundamental?**
#
# * 📊 **Estándar de la industria** - Usado en 95% de empresas
# * 🔍 **Consultar datos** - Extraer información de bases de datos
# * 🚀 **Optimizado** - Procesa millones de filas en segundos
# * 💼 **Skill crítico** - Requerido en análisis, BI, data engineering
#
# ---
#
# ### 📖 Sintaxis básica de SQL
#
# ```sql
# SELECT              -- ¿Qué columnas quiero?
#   columna1,
#   columna2
# FROM tabla          -- ¿De dónde?
# WHERE condicion     -- ¿Con qué filtros?
# ORDER BY columna    -- ¿En qué orden?
# LIMIT 10;           -- ¿Cuántas filas?
# ```
#
# ---
#
# ### 🎯 Funciones SQL integradas
#
# Databricks incluye funciones SQL poderosas:
#
# | Función | Propósito | Ejemplo |
# |---------|-----------|----------|
# | `CURRENT_DATE()` | Fecha de hoy | `2024-01-15` |
# | `CURRENT_TIMESTAMP()` | Fecha y hora actual | `2024-01-15 14:30:00` |
# | `CONCAT()` | Unir textos | `CONCAT('Hola', ' ', 'Mundo')` |
# | `UPPER()` / `LOWER()` | Cambiar case | `UPPER('sql')` → `'SQL'` |
# | `LENGTH()` | Longitud de texto | `LENGTH('Databricks')` → `11` |
#
# ---
#
# ### 🧪 Ejercicio 2: Tu primera query
#
# La siguiente celda SQL:
#
# ✅ Usa `SELECT` para crear columnas calculadas
# ✅ No consulta ninguna tabla (valores literales)
# ✅ Demuestra funciones de fecha y operaciones aritméticas
# ✅ Muestra el resultado como tabla automáticamente
#
# **💡 Nota importante:** En Databricks, las celdas SQL se ejecutan usando el **Spark SQL engine**, que soporta SQL ANSI estándar + extensiones.
#
# **⚡ Ejecuta la celda SQL y observa el resultado tabular**

# %% [markdown]
# ## 🔧 6. Comandos Shell en Databricks
#
# ### 🐧 Shell: La línea de comandos de Linux
#
# **¿Qué son los comandos shell?**
#
# Comandos de terminal de Linux/Unix que permiten:
#
# * 📁 **Explorar archivos** - `ls`, `pwd`, `cd`
# * 📄 **Ver contenido** - `cat`, `head`, `tail`
# * 🔽 **Descargar datos** - `wget`, `curl`
# * 📦 **Instalar paquetes** - `pip install`
# * 💻 **Información del sistema** - `df`, `free`, `top`
#
# ---
#
# ### ⚡ Magic Commands en Databricks
#
# Databricks usa **"magic commands"** para cambiar de lenguaje dentro de un notebook:
#
# ```python
# %python    # Ejecutar Python (default)
# %sql       # Ejecutar SQL
# %md        # Escribir Markdown
# %sh        # Ejecutar Shell commands
# %r         # Ejecutar R (si está disponible)
# %scala     # Ejecutar Scala
# ```
#
# **Ejemplo de uso:**
# ```python
# %sh ls /dbfs/FileStore/
# ```
#
# ---
#
# ### 🔒 Limitaciones en Serverless Compute
#
# En Databricks **Serverless** (Free Edition), los comandos shell están **restringidos por seguridad**:
#
# **✅ Disponibles:**
# * `ls`, `pwd`, `cat`, `echo` - Navegación básica
# * `python`, `pip` - Gestión de Python
# * `wget`, `curl` - Descarga de archivos
#
# **❌ No disponibles:**
# * `apt-get`, `yum` - Instalación de paquetes del sistema
# * `sudo` - Permisos de administrador
# * Acceso directo a Docker o recursos del host
#
# ---
#
# ### 💡 Alternativas a comandos shell
#
# En lugar de shell, usa:
#
# | En vez de... | Usa en Python |
# |--------------|---------------|
# | `%sh ls /dbfs/FileStore/` | `dbutils.fs.ls("/FileStore/")` |
# | `%sh cat file.txt` | `with open('file.txt') as f: print(f.read())` |
# | `%sh wget <url>` | `import requests; requests.get(url)` |
#
# **⚡ Ejecuta la celda siguiente para ver comandos disponibles**

# %%
# 💻 Ejercicio 1: Verificar que Python está funcionando

import sys
import platform
from datetime import datetime

print("✅ VERIFICACIÓN DEL ENTORNO DATABRICKS")
print("=" * 60)
print(f"\n🐍 Versión de Python: {sys.version.split()[0]}")
print(f"💻 Sistema Operativo: {platform.system()}")
print(f"📅 Fecha y Hora: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print(f"📁 Directorio de trabajo: {sys.executable}")

print("\n✅ ¡Python está funcionando correctamente en Databricks!")
print("\n💡 Siguiente: Ejecuta la celda SQL de abajo")

# %%
# %sql
-- 📊 Ejercicio 2: Tu primera consulta SQL en Databricks

SELECT 
  '¡Hola desde SQL!' AS mensaje,
  CURRENT_DATE() AS fecha_hoy,
  CURRENT_TIMESTAMP() AS hora_actual,
  1 + 1 AS resultado_suma,
  'Databricks Free Edition' AS plataforma;

-- 💡 Observa cómo el resultado se muestra en tabla automáticamente

# %% [markdown]
# ## 📂 7. Sistemas de Almacenamiento en Databricks
#
# ### 🗂️ DBFS (Databricks File System)
#
# **Definición:** Sistema de archivos distribuido que aparece como carpetas en Databricks.
#
# **Rutas comunes:**
# ```
# /FileStore/           → Archivos subidos por usuario
# /databricks-datasets/ → Datasets de ejemplo (incluidos)
# /user/hive/warehouse/ → Tablas de bases de datos
# /tmp/                 → Archivos temporales
# ```
#
# **Ejemplo de uso:**
# ```python
# # Leer archivo CSV desde DBFS
# df = spark.read.csv("/FileStore/ventas.csv", header=True)
#
# # Listar contenido de carpeta
# dbutils.fs.ls("/FileStore/")
#
# # Subir archivo
# dbutils.fs.cp("file:/local/path.csv", "/FileStore/path.csv")
# ```
#
# ---
#
# ### 🏭 Unity Catalog vs DBFS
#
# | Aspecto | DBFS | Unity Catalog |
# |---------|------|---------------|
# | **Disponibilidad** | ✅ Community Edition | ❌ Solo versión paga |
# | **Permisos** | Básicos (público) | Granulares (por usuario/grupo) |
# | **Organización** | Carpetas simples | Catalogs → Schemas → Tables |
# | **Gobernanza** | Limitada | Avanzada (auditoría, linaje) |
# | **Ideal para** | Aprendizaje, prototipos | Producción empresarial |
#
# **Para este libro:** Usaremos **DBFS** exclusivamente, suficiente para aprender.
#
# ---
#
# ### 🎯 Casos de uso prácticos
#
# #### Escenario 1: Subir archivo CSV desde tu computadora
# ```python
# # El usuario sube via UI → el archivo queda en /FileStore/
# df = spark.read.csv("/FileStore/ventas_2024.csv", header=True, inferSchema=True)
# df.show(5)
# ```
#
# #### Escenario 2: Leer dataset de ejemplo incluido
# ```python
# # Databricks incluye datasets públicos
# df = spark.read.format("csv") \
#   .option("header", "true") \
#   .load("/databricks-datasets/retail-org/customers/customers.csv")
# ```
#
# #### Escenario 3: Guardar resultados procesados
# ```python
# # Guardar DataFrame como tabla Delta
# df_resultado.write.format("delta").mode("overwrite").saveAsTable("mi_analisis")
#
# # La tabla queda en: /user/hive/warehouse/mi_analisis
# ```
#
# ---
#
# ### 💡 Tips importantes
#
# **✅ Buenas prácticas:**
# * Usa **Delta Lake** siempre que sea posible (transacciones ACID, versionamiento)
# * Organiza archivos en carpetas lógicas (`/FileStore/proyectos/retail/`)
# * Nombra tablas descriptivamente (`ventas_2024_limpio`, no `tabla1`)
#
# **❌ Evita:**
# * Archivos CSV gigantes (>1 GB) sin particionamiento
# * Nombres de tabla con espacios o caracteres especiales
# * Guardar datos sensibles sin permisos en DBFS (en producción usar Unity Catalog)
#
# ---
#
# ### 💾 Tablas en Databricks
#
# **Tipos de tablas:**
#
# 1. **Managed Tables** (gestionadas)
#    - Databricks controla datos + metadatos
#    - Al borrar tabla, se borran los datos
#    - Ubicación: `/user/hive/warehouse/`
#
# 2. **External Tables** (externas)
#    - Datos en ubicación externa (S3, Azure Blob)
#    - Al borrar tabla, datos persisten
#    - Útil para datos compartidos
#
# **Formatos soportados:**
# * Delta Lake (recomendado) - transacciones ACID, time travel
# * Parquet - columnar, comprimido
# * CSV - simple, poco eficiente
# * JSON - semi-estructurado

# %%
# ⚙️ Ejercicio 3: Explorar el sistema de archivos con comandos shell

print("🔧 COMANDOS SHELL EN DATABRICKS")
print("=" * 60)

print("\n💡 En Databricks puedes ejecutar comandos shell con %sh magic")
print("\nEjemplos comunes:")
print("""  
# %sh ls /dbfs/FileStore/              # Listar archivos
# %sh pwd                              # Directorio actual  
# %sh df -h                            # Espacio en disco
# %sh cat /dbfs/FileStore/archivo.txt  # Ver contenido
# %sh wget <url> -P /dbfs/FileStore/   # Descargar archivo
""")

print("\n⚠️ Nota: En Serverless, algunos comandos shell pueden estar limitados")
print("\n✅ Comandos funcionando en Serverless:")
print("   - ls, pwd, cat, echo")
print("   - python, pip")
print("\n❌ No disponibles en Serverless:")
print("   - apt-get, yum (gestores de paquetes del sistema)")
print("   - sudo (permisos de administrador)")

# %% [markdown]
# ## 🐙 8. Integración con GitHub (Git Repos)
#
# ### 🎯 ¿Por qué usar Git con Databricks?
#
# **Problema sin Git:**
# ```
# Notebook_v1.ipynb
# Notebook_v2_final.ipynb
# Notebook_v2_final_REAL.ipynb
# Notebook_v2_final_REAL_ahora_si.ipynb  😱
# ```
#
# **Con Git:**
# * ✅ Historial completo de cambios
# * ✅ Colaboración sin conflictos
# * ✅ Volver a versiones anteriores
# * ✅ Backup automático en la nube
# * ✅ Code review profesional
#
# ---
#
# ### 📋 Pre-requisitos
#
# 1. **Cuenta de GitHub** (gratis): https://github.com/signup
# 2. **Repositorio creado** en GitHub
# 3. **Personal Access Token (PAT)** de GitHub
#
# ---
#
# ### 🔑 Paso 1: Crear Personal Access Token
#
# **En GitHub:**
#
# 1. Ve a: **Settings → Developer settings → Personal access tokens → Tokens (classic)**
# 2. Click **"Generate new token (classic)"**
# 3. **Note:** "Databricks Access"
# 4. **Expiration:** 90 days (o más)
# 5. **Scopes** (permisos):
#    * ✅ `repo` (acceso completo a repositorios)
#    * ✅ `workflow` (si usas GitHub Actions)
# 6. Click **"Generate token"**
# 7. **⚠️ IMPORTANTE:** Copia el token y guárdalo (solo se muestra una vez)
#
# **Formato del token:** `ghp_xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx`
#
# ---
#
# ### 🔗 Paso 2: Conectar GitHub con Databricks
#
# **Método 1: Databricks Repos (Recomendado)**
#
# 1. En Databricks, panel izquierdo → **Repos**
# 2. Click **"Add Repo"**
# 3. **Git repository URL:** `https://github.com/tu-usuario/tu-repo.git`
# 4. **Git provider:** GitHub
# 5. **Git credential:** Paste tu Personal Access Token
# 6. Click **"Create"**
#
# **Método 2: Clonar repo existente**
#
# 1. Panel **Repos** → **"Add Repo"**
# 2. Pega URL del repo público
# 3. Si es privado, necesitas el token
#
# ---
#
# ### 📁 Estructura recomendada de Proyecto
#
# ```
# mi-proyecto/
# ├── notebooks/              # Notebooks interactivos
# │   ├── 01_exploracion.py
# │   ├── 02_limpieza.py
# │   └── 03_analisis.py
# ├── src/                    # Código Python modular
# │   ├── utils.py
# │   └── config.py
# ├── data/                   # Datos de ejemplo (pequeños)
# │   └── sample.csv
# ├── tests/                  # Tests unitarios
# │   └── test_utils.py
# ├── README.md               # Documentación
# └── requirements.txt        # Dependencias Python
# ```
#
# ---
#
# ### 🎯 Ejemplo paso a paso
#
# **1. Crear repositorio en GitHub:**
# ```
# Nombre: saliendo-de-lo-pandito
# Descripción: Notebooks del libro Databricks
# Visibilidad: Público o Privado
# ☑️ Agregar README.md
# ```
#
# **2. Obtener URL del repo:**
# ```
# https://github.com/tu-usuario/saliendo-de-lo-pandito.git
# ```
#
# **3. En Databricks Repos:**
# * Panel izquierdo → **Repos**
# * Click **"Add Repo"** (botón azul arriba)
# * Pegar URL del repo
# * Si es privado: agregar Personal Access Token
# * Click **"Create"**
#
# **4. Resultado:**
#
# Ahora tienes una carpeta en tu workspace sincronizada con GitHub. Cualquier cambio que hagas en notebooks dentro de esa carpeta puede ser versionado con Git.
#
# ---
#
# ### ✅ Verificación rápida
#
# **¿Cómo saber si tu repo está conectado?**
#
# 1. Ve a panel **Repos** (icono de carpeta con rama)
# 2. Deberías ver tu repositorio listado
# 3. Haz click en él → verás tus notebooks
# 4. En la esquina superior derecha verás: `main` (branch actual)
#
# **¿Dónde está el icono de Git?**
#
# Cuando abres un notebook **dentro de un Repo**, verás en la parte superior:
# * Icono de **rama** (🌿) → Branch actual
# * Icono de **reloj** (🕐) → Historial de commits
# * Botón **"Git..."** → Menú de operaciones Git

# %% [markdown]
# ## 🔄 9. Git Operations - Flujo de Trabajo
#
# ### 🔄 Flujo de Trabajo Git
#
# ```text
# 1. PULL    → Traer cambios del repo remoto
# 2. EDIT    → Modificar notebooks
# 3. COMMIT  → Guardar cambios localmente
# 4. PUSH    → Enviar cambios al repo remoto
# ```
#
# ### 📏 Operaciones básicas
#
# #### 1️⃣ Pull (Actualizar desde GitHub)
#
# **Cuándo:** Antes de empezar a trabajar
#
# **Cómo:**
#
# 1. En Databricks Repos, click en el nombre del repo
# 2. Click **"Pull"** (botón con flecha hacia abajo)
# 3. Confirma que estás en la rama correcta
#
# #### 2️⃣ Commit (Guardar cambios)
#
# **Cuándo:** Después de hacer cambios significativos
#
# **Cómo:**
#
# 1. Click en el nombre del repo
# 2. Click **"Git..."** → **"Commit"**
# 3. Escribe un mensaje descriptivo:
#    * ✅ Bien: "Agregar análisis de ventas por región"
#    * ❌ Mal: "update", "fix", "cambios"
# 4. Click **"Commit & Push"**
#
# #### 3️⃣ Push (Enviar a GitHub)
#
# **Cuándo:** Después de commit, para sincronizar
#
# **Cómo:**
#
# * Si usaste "Commit & Push", ya está hecho
# * Si no, click **"Git..."** → **"Push"**
#
# #### 4️⃣ Branching (Ramas)
#
# **Para qué:** Trabajar en features sin afectar `main`
#
# **Crear rama:**
#
# 1. **"Git..."** → **"Create Branch"**
# 2. Nombre: `feature/analisis-ventas`
# 3. Work on that branch
# 4. Merge to main cuando esté listo
#
# ### ⚠️ Conflictos de Merge
#
# **Pasan cuando:** Dos personas editan la misma línea
#
# **Resolución:**
#
# 1. Databricks te avisa del conflicto
# 2. Abre el archivo con conflicto
# 3. Busca marcadores:
#
#    ```text
#    <<<<<<< HEAD
#    Tu versión
#    =======
#    Versión remota
#    >>>>>>> origin/main
#    ```
#
# 4. Edita manualmente para resolver
# 5. Commit de la resolución
#
# ### 💡 Mejores Prácticas en Git
#
# * ✅ Commit frecuentemente (cada feature pequeño)
# * ✅ Mensajes de commit descriptivos
# * ✅ Pull antes de empezar a trabajar
# * ✅ Usa branches para features grandes
# * ✅ Haz code review antes de merge a main
# * ❌ NO hagas commit de datos sensibles (contraseñas, API keys)
# * ❌ NO hagas commit de archivos grandes (>100 MB)
#
# ### 📊 Ejemplo de flujo completo
#
# **Escenario:** Crear análisis de ventas y subirlo a GitHub
#
# **Paso 1: Trabajar en tu notebook**
#
# 1. Abre notebook dentro del Repo
# 2. Escribe código Python/SQL
# 3. Ejecuta y verifica resultados
# 4. Databricks auto-guarda cada 30 segundos
#
# **Paso 2: Revisar cambios**
#
# 1. Click en "Git..." (esquina superior)
# 2. Ver lista de archivos modificados
# 3. Ver diff (qué cambió)
#
# **Paso 3: Commit local**
#
# 1. Click "Commit"
# 2. Mensaje: "Agregar análisis de ventas Q1 2024"
# 3. Seleccionar archivos a incluir
# 4. Click "Commit & Push"
#
# **Paso 4: Verificar en GitHub**
#
# 1. Ve a github.com/tu-usuario/tu-repo
# 2. Deberías ver tu commit más reciente
# 3. El notebook aparece como archivo .py o .ipynb
#
# ### 🚀 Comandos Git equivalentes
#
# Si prefieres usar comandos Git (en terminal):
#
# ```bash
# # Ver cambios
# git status
#
# # Agregar archivos al stage
# git add notebook.py
#
# # Commit
# git commit -m "Agregar análisis de ventas"
#
# # Push a GitHub
# git push origin main
#
# # Pull desde GitHub
# git pull origin main
# ```
#
# **Nota:** En Databricks Repos, estos comandos se ejecutan a través de la UI, no necesitas terminal.

# %% [markdown]
# ## ✅ 10. Checklist: ¿Tu entorno está listo?
#
# ### 🎯 Validación Final
#
# Marca cada item al completarlo:
#
# #### Databricks
# * ☐ Cuenta creada en Free Edition
# * ☐ Puedes acceder al workspace
# * ☐ Ejecutaste código Python exitosamente
# * ☐ Ejecutaste consulta SQL exitosamente
# * ☐ Conoces dónde está DBFS
# * ☐ Entiendes qué es un notebook
# * ☐ Sabes cómo crear carpetas
#
# #### GitHub
# * ☐ Cuenta de GitHub creada
# * ☐ Repositorio creado (público o privado)
# * ☐ Personal Access Token generado y guardado
# * ☐ Repo clonado en Databricks
# * ☐ Hiciste tu primer commit
# * ☐ Cambios visibles en GitHub
#
# #### Conceptos
# * ☐ Entiendes qué es Serverless Compute
# * ☐ Sabes la diferencia entre DBFS y Unity Catalog
# * ☐ Conoces los tipos de celdas en notebooks
# * ☐ Sabes usar comandos mágicos (%md, %sql, %sh)
# * ☐ Entiendes el flujo Git (pull, commit, push)
#
# ---
#
# ### 🚨 Troubleshooting común
#
# #### Problema: "Cluster no inicia"
# **Solución:** En Free Edition usas Serverless. No hay botón "Start Cluster". Simplemente ejecuta una celda.
#
# #### Problema: "Git credential inválido"
# **Solución:**
# 1. Verifica que tu Personal Access Token esté vigente
# 2. Asegúrate de copiar el token completo
# 3. Scope `repo` debe estar habilitado
#
# #### Problema: "No puedo ver mi repo en Databricks"
# **Solución:**
# 1. Verifica que la URL del repo sea correcta
# 2. Si es privado, necesitas credentials
# 3. Intenta clonar de nuevo
#
# #### Problema: "Notebook no guarda cambios"
# **Solución:**
# 1. Databricks autoguarda cada pocos segundos
# 2. Para Git, necesitas commit explícito
# 3. Check en "Git Status" si hay cambios pendientes
#
# ---
#
# ---
#
# ### 🎯 Cómo usar este checklist
#
# **Recomendación:** Imprime o copia esta lista y márcala a medida que completas cada item.
#
# **🚦 Semáforo de progreso:**
# * 🟢 **Verde** (todos los ☑️ de Databricks + GitHub) → ¡Listo para continuar!
# * 🟡 **Amarillo** (Databricks completo, GitHub pendiente) → Puedes avanzar, pero configura Git pronto
# * 🔴 **Rojo** (items críticos de Databricks sin ☑️) → Revisa troubleshooting
#
# ---
#
# ### 📊 Siguiente paso: Verificación automática
#
# **Ejecuta la celda siguiente (Script de Verificación) para validar tu entorno completo automáticamente**

# %% [markdown]
#
# ## 🧪 11. Script de Verificación del Entorno
#
# ### 🎯 Verificación automática completa
#
# Este script valida que todo tu entorno Databricks esté correctamente configurado y funcionando:
#
# * ✅ **Python** - Versión y ejecución
# * ✅ **Bibliotecas core** - Pandas, NumPy, PySpark
# * ✅ **Spark Session** - Motor de procesamiento activo
# * ✅ **SQL** - Consultas Spark SQL
# * ✅ **Filesystem** - Acceso a DBFS
#
# > 💡 **Ejecuta la celda de abajo** para validar tu entorno automáticamente.

# %%
# 🧪 11. Script de Verificación Completa del Entorno

import sys
import os
from datetime import datetime

print("🔍 VERIFICACIÓN COMPLETA DEL ENTORNO")
print("=" * 70)

# Test 1: Python
print("\n✅ TEST 1: Python")
print(f"   Versión: {sys.version.split()[0]}")
print(f"   Executable: {sys.executable}")
assert sys.version_info >= (3, 9), "Python debe ser 3.9+"
print("   ✓ Python OK")

# Test 2: Bibliotecas Core
print("\n✅ TEST 2: Bibliotecas Esenciales")
try:
    import pandas as pd
    import numpy as np
    from pyspark.sql import SparkSession
    print(f"   Pandas: {pd.__version__}")
    print(f"   NumPy: {np.__version__}")
    print("   PySpark: Disponible")
    print("   ✓ Bibliotecas OK")
except ImportError as e:
    print(f"   ✗ Error: {e}")

# Test 3: Spark Session
print("\n✅ TEST 3: Spark Session")
try:
    df_test = spark.range(10).selectExpr("id", "id * 2 as doble")
    count = df_test.count()
    print(f"   Spark activo: {spark.version}")
    print(f"   Test DataFrame: {count} filas")
    print("   ✓ Spark OK")
except Exception as e:
    print(f"   ✗ Error: {e}")

# Test 4: SQL
print("\n✅ TEST 4: SQL")
try:
    result = spark.sql("SELECT 1+1 as resultado").collect()[0][0]
    assert result == 2
    print("   SQL ejecutado exitosamente")
    print("   ✓ SQL OK")
except Exception as e:
    print(f"   ✗ Error: {e}")

# Test 5: Sistema de archivos
print("\n✅ TEST 5: Acceso a Filesystem")
try:
    # En Serverless, dbutils puede no estar disponible en todos los contextos
    if 'dbutils' in dir():
        files = dbutils.fs.ls("/")
        print(f"   DBFS accesible: {len(files)} items en raíz")
        print("   ✓ DBFS OK")
    else:
        print("   ⚠️  dbutils no disponible en este contexto (normal en Serverless)")
        print("   ✓ Filesystem básico OK")
except Exception as e:
    print(f"   ⚠️  DBFS limitado: {e}")

# Resumen
print("\n" + "=" * 70)
print("📊 RESUMEN")
print("=" * 70)
print("✅ Python ................... OK")
print("✅ Bibliotecas .............. OK") 
print("✅ Spark .................... OK")
print("✅ SQL ...................... OK")
print("✅ Filesystem ............... OK (con limitaciones normales en Serverless)")
print("\n🎉 ¡TU ENTORNO DATABRICKS ESTÁ COMPLETAMENTE FUNCIONAL!")
print("\n📚 Estás listo para continuar con el Módulo 01 - Notebook 02")
print("   → Introducción a Python en Databricks")

# %% [markdown]
# ## 🎓 12. Conclusiones y próximos pasos
#
# ### ✅ Lo que aprendiste en este notebook
#
# #### Fundamentos de Databricks
# 1. 🏛️ **Qué es Databricks** y su arquitectura (Workspace, Compute, Storage)
# 2. ⚙️ **Diferencia entre Serverless y All-Purpose Clusters**
# 3. 📚 **Anatomía de notebooks** interactivos
#
# #### Primeros pasos prácticos
# 4. 🐍 **Ejecutar código Python** en Databricks
# 5. 🔷 **Ejecutar consultas SQL** con Spark SQL
# 6. 🔧 **Comandos shell** y magic commands
#
# #### Almacenamiento y versionamiento
# 7. 📂 **DBFS vs Unity Catalog** y cómo trabajar con archivos
# 8. 🐙 **Configurar Git integration** con GitHub
# 9. 🔄 **Flujo de trabajo Git** (pull, commit, push, branches)
#
# #### Validación
# 10. 🧪 **Script de verificación completa** del entorno
# 11. ✅ **Checklist** de configuración correcta
#
# ### 🚀 Próximos notebooks de este módulo
#
# * **01_02** - Introducción a Python en Databricks
#   - Variables, tipos de datos, operadores
#   - Listas, diccionarios, tuplas, sets
#   - Ejercicios prácticos de negocio
#
# * **01_03** - Estructuras de Control y Funciones
#   - Condicionales (if/elif/else)
#   - Bucles (for/while)
#   - Funciones reutilizables
#   - Lambda functions
#
# * **01_04** - Entorno Interactivo Jupyter
#   - Comandos mágicos (%md, %sql, %sh)
#   - Atajos de teclado
#   - Markdown avanzado
#   - Debugging y organización
#
# ---
#
# ## 💪 Reto personal
#
# **Antes de continuar al siguiente notebook:**
#
# 1. ✅ Confirma que ejecutaste todas las celdas exitosamente
# 2. ✅ Verifica que tu repo de GitHub esté sincronizado
# 3. ✅ Practica hacer un commit de este notebook
# 4. ✅ Explora las carpetas de DBFS (`/FileStore/`, `/databricks-datasets/`)
#
# ---
#
# ### 📚 Continúa tu aprendizaje
#
# **Siguiente notebook:** [01_02_Introduccion_a_Python_en_Databricks](#notebook-1387333169793341)
#
# ---
#
# ### 📊 Tiempo invertido vs. Valor obtenido
#
# | Sección | Tiempo | Valor de negocio |
# |---------|--------|------------------|
# | Registro en Databricks | 5 min | Acceso a plataforma profesional gratis |
# | Primer código Python/SQL | 10 min | Validar que puedes ejecutar análisis |
# | Git configuration | 15 min | Versionamiento profesional (crucial en equipos) |
# | **TOTAL** | **30 min** | **Base sólida para tu carrera en datos** |
#
# ---
#
# ### 🏆 Habilidades desbloqueadas
#
# Al completar este notebook, ahora puedes:
#
# ✅ Trabajar en un entorno de datos profesional (Databricks)
# ✅ Ejecutar análisis con Python y SQL
# ✅ Versionar tu trabajo con Git (como desarrolladores de software)
# ✅ Colaborar en proyectos de datos con tu equipo
# ✅ Prepararte para certificaciones Databricks
#
# ---
#
# <div style="background: linear-gradient(90deg, #1e3a8a 0%, #3b82f6 100%); padding: 20px; border-radius: 10px; color: white; text-align: center;">
#   <h3>🚀 ¡Tu entorno Databricks está 100% funcional!</h3>
#   <p><i>"La configuración es el 20% del trabajo que desbloquea el 80% del valor."</i></p>
#   <p><b>Ahora es momento de aprender Python para análisis de datos →</b></p>
# </div>
