# %% [markdown]
# # Saliendo de lo Pandito v4
# ## Módulo 1: Entorno de Trabajo Unificado con Databricks Free Edition & GitHub
#
# ### Objetivos del Módulo:
# 1. Configurar la plataforma **Databricks Free Edition (Community Cloud)** para ejecución en la nube.
# 2. Comprender la arquitectura de **DBFS (Databricks File System)** y **Unity Catalog**.
# 3. Sincronizar cuadernos de trabajo interactivos con **GitHub Repos**.
# 4. Establecer las buenas prácticas de desarrollo para el analista de negocios.

# %%
# Verificación del entorno de ejecución en Databricks / Python
import sys
import os

print(f"Versión de Python: {sys.version}")
print("Plataforma lista para ejecución en Databricks Free Edition / Google Colab")
