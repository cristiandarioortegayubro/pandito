# %% [markdown]
# # Saliendo de lo Pandito v4
# ## Gráficos Interactivos de Barras, Dispersión y Líneas
#
# Este notebook forma parte del material práctico oficial del libro **Saliendo de lo Pandito v4**.
# Plataforma de ejecución: **Databricks Free Edition** / Google Colab.
# Orientado a profesionales de Ciencias Económicas (Contadores Públicos, Lic. en Administración, Lic. en Economía) y Analistas de Datos de Negocios.

# %%
# 🎯 OPCIONAL: Usar datos reales de Unity Catalog para visualizaciones

# Descomentar para usar datos reales:
"""
import pandas as pd
import plotly.express as px

print("💾 Cargando datos reales desde Unity Catalog...")

CATALOG = "pandito_ds"
SCHEMA = "default"

try:
    df_ventas = spark.table(f"{CATALOG}.{SCHEMA}.ventas_mensuales_mendoza_h3").toPandas()
    df_ventas['fecha'] = pd.to_datetime(df_ventas['fecha'])
    
    print(f"✅ Datos reales cargados: {len(df_ventas):,} registros")
    print(f"   Sucursales: {df_ventas['sucursal_id'].nunique()}")
    print(f"\n📊 Ejemplos de gráficos con Plotly Express:")
    
    # Ejemplo 1: Gráfico de líneas - Evolución por sucursal
    print("\n1️⃣ Líneas - Evolución temporal:")
    print("   fig = px.line(df_ventas, x='fecha', y='ventas', color='sucursal_id')")
    
    # Ejemplo 2: Barras - Comparación entre zonas
    print("\n2️⃣ Barras - Ventas por zona:")
    print("   df_zona = df_ventas.groupby('zona')['ventas'].sum().reset_index()")
    print("   fig = px.bar(df_zona, x='zona', y='ventas')")
    
    # Ejemplo 3: Scatter - Relación geográfica
    print("\n3️⃣ Scatter - Ventas vs Ubicación:")
    print("   fig = px.scatter(df_ventas, x='lon', y='lat', size='ventas',")
    print("                    color='zona', hover_name='sucursal_nombre')")
    
    display(df_ventas.head())
    
except Exception as e:
    print(f"⚠️  Tabla no encontrada: {e}")
    print("   Ejecuta primero: 00_05_Preparacion_Datos_Empresariales.ipynb")
"""

print("ℹ️  Usando datos sintéticos de este notebook")
print("="*70)

# %%
# Código de inicialización de notebook reindexado
import pandas as pd
import numpy as np
print('Notebook reindexado listo para práctica en Databricks')
