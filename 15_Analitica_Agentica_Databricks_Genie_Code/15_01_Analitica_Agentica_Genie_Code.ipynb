# %% [markdown]
# # Saliendo de lo Pandito v4
# ## Módulo 15: Analítica Agéntica e Inteligencia Artificial con Databricks Genie Code & Assistant
#
# ### Objetivos del Módulo:
# 1. Comprender la arquitectura de **Analítica Agéntica** sobre el Lakehouse de Databricks.
# 2. Utilizar **Databricks Genie Code** y **Databricks Assistant** para generación automática de PySpark/SQL.
# 3. Formular preguntas complejas de negocio en lenguaje natural y obtener respuestas analíticas verificadas.
# 4. Refactorizar y depurar agénticamente scripts y consultas extensas.

# %%
# Plantilla demostrativa de Prompt Agéntico para Databricks Genie Code
prompt_agentico = """
[AGENTE ANALÍTICO DE NEGOCIOS]
Instrucción: Genera un pipeline PySpark que lea la tabla Delta 'ventas_corporativas',
filtre los registros del último trimestre, calcule el EBITDA acumulado por sucursal
y devuelva el gráfico Waterfall en Plotly con las variaciones.
"""

print("Prompt Agéntico configurado para Databricks Genie Code / Assistant:")
print(prompt_agentico)
