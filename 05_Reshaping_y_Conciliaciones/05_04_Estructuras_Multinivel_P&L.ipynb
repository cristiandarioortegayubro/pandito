# %%
# 🎯 OPCIONAL: Estructuras multinivel con datos reales
"""
import pandas as pd
CATALOG, SCHEMA = "pandito_ds", "default"
try:
    df = spark.table(f"{CATALOG}.{SCHEMA}.ventas_mensuales_mendoza_h3").toPandas()
    df['fecha'] = pd.to_datetime(df['fecha'])
    df['mes'] = df['fecha'].dt.month; df['año'] = df['fecha'].dt.year
    # Crear índice multinivel
    df_multi = df.set_index(['año', 'mes', 'sucursal_id'])
    print(f"✅ Estructura multinivel creada")
    print("\nEjemplos de acceso:")
    print("  df_multi.loc[2019]  # Todos los datos de 2019")
    print("  df_multi.loc[(2019, 1)]  # Enero 2019")
    print("  df_multi.loc[(2019, 1, 'SUC001')]  # Enero 2019, SUC001")
    display(df_multi.head(10))
except: print("⚠️  Ejecuta primero 00_05")
"""
print("ℹ️  Usando datos sintéticos")

# %% [markdown]
# # Saliendo de lo Pandito
# ## Índices Jerárquicos Multinivel para Estados P&L
#
# Este notebook forma parte del material práctico oficial del libro **Saliendo de lo Pandito**.
# Plataforma de ejecución: **Databricks Free Edition** / Google Colab.
# Orientado a profesionales de Ciencias Económicas (Contadores Públicos, Lic. en Administración, Lic. en Economía) y Analistas de Datos de Negocios.

# %%
# Código de inicialización de notebook reindexado
import pandas as pd
import numpy as np
print('Notebook reindexado listo para práctica en Databricks')
